# %% [markdown]
# # Visualización de Base de Datos de Exoplanetas

# %% [markdown]
# ![alt text](https://ep01.epimg.net/portadillasetiquetas/imagenes/2017/02/23/portadilla/1487865835_992873_1487865974_portadilla_normal.jpg)

# %% [markdown]
# # Motivación

# %% [markdown]
# La investigación de planetas extra solares es una área de la astronomía que a crecido debido al lanzamiento de nuevos y poderosos observatorios astronómicos espaciales, así mismo la cantidad de datos que estas investigaciones arrojan han crecido bastante, a continuación se muestra la visualización de una base de datos que cataloga las características observadas en los planetas extra solares que se han descubierto.
# [Fuente](http://exoplanet.eu/catalog/all_fields/)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv('exoplanet.eu_catalog.csv')

# %% [markdown]
# # Exploración de Datos

# %%
df.head()
# Out:
#      # name planet_status  mass  mass_error_min  mass_error_max  mass_sini  \
# 0  11 Com b     Confirmed   NaN             NaN             NaN      19.40
# 1  11 Oph b     Confirmed  21.0             3.0             3.0        NaN
# 2  11 UMi b     Confirmed   NaN             NaN             NaN      10.50
# 3  14 And b     Confirmed   NaN             NaN             NaN       5.33
# 4  14 Her b     Confirmed   NaN             NaN             NaN       4.64
#
#    mass_sini_error_min  mass_sini_error_max  radius  radius_error_min  ...  \
# 0                 1.50                 1.50     NaN               NaN  ...
# 1                  NaN                  NaN     NaN               NaN  ...
# 2                 2.47                 2.47     NaN               NaN  ...
# 3                 0.57                 0.57     NaN               NaN  ...
# 4                 0.19                 0.19     NaN               NaN  ...
#
#    star_sp_type  star_age  star_age_error_min  star_age_error_max  star_teff  \
# 0        G8 III       NaN                 NaN                 NaN     4742.0
# 1            M9     0.011               0.002               0.002     2375.0
# 2         K4III     1.560               0.540               0.540     4340.0
# 3         K0III       NaN                 NaN                 NaN     4813.0
# 4          K0 V     5.100                 NaN                 NaN     5311.0
#
#    star_teff_error_min  star_teff_error_max  star_detected_disc  \
# 0                100.0                100.0                 NaN
# 1                175.0                175.0                 NaN
# 2                 70.0                 70.0                 NaN
# 3                 20.0                 20.0                 NaN
# 4                 87.0                 87.0                 NaN
#
#    star_magnetic_field    star_alternate_names
# 0                  NaN                     NaN
# 1                  NaN  Oph 1622-2405, Oph 11A
# 2                  NaN                     NaN
# 3                  NaN                     NaN
# 4                  NaN                     NaN
#
# [5 rows x 98 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4404 entries, 0 to 4403
# Data columns (total 98 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   # name                      4404 non-null   object
#  1   planet_status               4404 non-null   object
#  2   mass                        1332 non-null   float64
#  3   mass_error_min              1255 non-null   float64
#  4   mass_error_max              1244 non-null   float64
#  5   mass_sini                   1009 non-null   float64
#  6   mass_sini_error_min         858 non-null    float64
#  7   mass_sini_error_max         858 non-null    float64
#  8   radius                      3227 non-null   float64
#  9   radius_error_min            3124 non-null   float64
#  10  radius_error_max            3124 non-null   float64
#  11  orbital_period              4141 non-null   float64
#  12  orbital_period_error_min    3991 non-null   float64
#  13  orbital_period_error_max    3991 non-null   float64
#  14  semi_major_axis             2856 non-null   float64
#  15  semi_major_axis_error_min   1837 non-null   float64
#  16  semi_major_axis_error_max   1837 non-null   float64
#  17  eccentricity                1755 non-null   float64
#  18  eccentricity_error_min      1415 non-null   float64
#  19  eccentricity_error_max      1405 non-null   float64
#  20  inclination                 1054 non-null   float64
#  21  inclination_error_min       989 non-null    float64
#  22  inclination_error_max       991 non-null    float64
#  23  angular_distance            660 non-null    float64
#  24  discovered                  4399 non-null   float64
#  25  updated                     4404 non-null   object
#  26  omega                       1092 non-null   float64
#  27  omega_error_min             1019 non-null   float64
#  28  omega_error_max             1019 non-null   float64
#  29  tperi                       682 non-null    float64
#  30  tperi_error_min             629 non-null    float64
#  31  tperi_error_max             629 non-null    float64
#  32  tconj                       30 non-null     float64
#  33  tconj_error_min             31 non-null     float64
#  34  tconj_error_max             31 non-null     float64
#  35  tzero_tr                    945 non-null    float64
#  36  tzero_tr_error_min          892 non-null    float64
#  37  tzero_tr_error_max          892 non-null    float64
#  38  tzero_tr_sec                33 non-null     float64
#  39  tzero_tr_sec_error_min      31 non-null     float64
#  40  tzero_tr_sec_error_max      31 non-null     float64
#  41  lambda_angle                70 non-null     float64
#  42  lambda_angle_error_min      71 non-null     float64
#  43  lambda_angle_error_max      71 non-null     float64
#  44  impact_parameter            560 non-null    float64
#  45  impact_parameter_error_min  545 non-null    float64
#  46  impact_parameter_error_max  545 non-null    float64
#  47  tzero_vr                    37 non-null     float64
#  48  tzero_vr_error_min          34 non-null     float64
#  49  tzero_vr_error_max          34 non-null     float64
#  50  k                           932 non-null    float64
#  51  k_error_min                 928 non-null    float64
#  52  k_error_max                 928 non-null    float64
#  53  temp_calculated             590 non-null    float64
#  54  temp_calculated_error_min   324 non-null    float64
#  55  temp_calculated_error_max   324 non-null    float64
#  56  temp_measured               48 non-null     float64
#  57  hot_point_lon               2 non-null      float64
#  58  geometric_albedo            13 non-null     float64
#  59  geometric_albedo_error_min  11 non-null     float64
#  60  geometric_albedo_error_max  11 non-null     float64
#  61  log_g                       26 non-null     float64
#  62  publication                 4404 non-null   object
#  63  detection_type              4404 non-null   object
#  64  mass_detection_type         1220 non-null   object
#  65  radius_detection_type       806 non-null    object
#  66  alternate_names             489 non-null    object
#  67  molecules                   81 non-null     object
#  68  star_name                   4349 non-null   object
#  69  ra                          4404 non-null   float64
#  70  dec                         4404 non-null   float64
#  71  mag_v                       1955 non-null   float64
#  72  mag_i                       96 non-null     float64
#  73  mag_j                       2114 non-null   float64
#  74  mag_h                       2099 non-null   float64
#  75  mag_k                       2137 non-null   float64
#  76  star_distance               3197 non-null   float64
#  77  star_distance_error_min     1622 non-null   float64
#  78  star_distance_error_max     1623 non-null   float64
#  79  star_metallicity            3746 non-null   float64
#  80  star_metallicity_error_min  2830 non-null   float64
#  81  star_metallicity_error_max  2830 non-null   float64
#  82  star_mass                   3935 non-null   float64
#  83  star_mass_error_min         3168 non-null   float64
#  84  star_mass_error_max         3168 non-null   float64
#  85  star_radius                 3774 non-null   float64
#  86  star_radius_error_min       3571 non-null   float64
#  87  star_radius_error_max       3571 non-null   float64
#  88  star_sp_type                1622 non-null   object
#  89  star_age                    1335 non-null   float64
#  90  star_age_error_min          1066 non-null   float64
#  91  star_age_error_max          1066 non-null   float64
#  92  star_teff                   3988 non-null   float64
#  93  star_teff_error_min         3718 non-null   float64
#  94  star_teff_error_max         3718 non-null   float64
#  95  star_detected_disc          87 non-null     object
#  96  star_magnetic_field         4 non-null      object
#  97  star_alternate_names        617 non-null    object
# dtypes: float64(84), object(14)
# memory usage: 3.3+ MB

# %% [markdown]
# # ¿Cuál es el sistema planetario más lejano detectado ?

# %%
max_distance = df[df['star_distance']==df['star_distance'].max()]['# name'].values[0]
print('El sistema planetario más lejano es:', max_distance)
# Out:
# El sistema planetario más lejano es: XTE J1751-305 b

# %% [markdown]
# # ¿Cuál es el sistema planetario más cercano detectado?

# %%
min_distance = df[df['star_distance']==df['star_distance'].min()]['# name'].values
print('El sistema planetario más cercano es el contiene los planetas :', min_distance[0], 'y', min_distance[1])
# Out:
# El sistema planetario más cercano es el contiene los planetas : Proxima Centauri b y Proxima Centauri c

# %% [markdown]
# # ¿Cuál es el nombre del planeta con mayor excentricidad y cuál es su valor?

# %%
max_ecc = df[df['eccentricity']==df['eccentricity'].max()]['# name'].values[0]
max_ecc_v = df['eccentricity'].max()
print('Planeta con mayor excentricidad:', max_ecc)
print('Excentricidad de: {max_ecc_v}'.format(max_ecc_v=max_ecc_v))
# Out:
# Planeta con mayor excentricidad: 2I/Borisov
# Excentricidad de: 3.155

# %% [markdown]
# # ¿Cuál es la masa promedio?

# %%
mass = df['mass'].mean()
print('El masa primedio es de:', mass, 'MJup')
# Out:
# El masa primedio es de: 6.073390693123794 MJup

# %% [markdown]
# # ¿Se relaciona la masa de los planetas con su radio? ¿Qué nos dice esto acerca de las composiciones de los planetas?

# %% [markdown]
# Para comprar los datos debemos tener algo con que comparar, para esto se va tener en cuenta las cantidades de la Tierra.

# %%
MJ = 1.9*(10)**(27)
MT = 5.9*(10)**(24)
m = MT/MJ
RJ = 69.911
RT = 6.371
r= RT/RJ

# %%
ax = df.plot(kind='scatter', x='radius',y='mass', logx=True, logy=True, s=10, figsize=(15,5))
#ax = df.plot(kind='scatter', x='radius',y='mass', s=50, figsize=(15,5))
ax.set_xlabel("Radio [RJupiter]")
ax.set_ylabel("Masa Planetaria [MJupiter]")
ax.set_title("Masa Planetaria en Función del Radio")
ax.hlines(y=m, xmin=1*10**(-1.5), xmax=10, linewidth=2, color='r')
ax.vlines(x=r, ymin=1*10**(-5), ymax=1*10**3, linewidth=2, color='r')
ax.set_xlim(1*10**(-1.5), 10)
ax.set_ylim(1*10**(-5), 1*10**3)
plt.show()

# %% [markdown]
# Se observa que para planetas con Masas y Radios parecidos a la tierra se tienen planetas rocosos y para planetas con característica como las de Júpiter se tiene planetas gaseosos o planetas con núcleo rocoso, debido a la gravedad y una atmosfera muy gruesa.

# %% [markdown]
# # ¿Cómo se relaciona los métodos de detección con los datos?

# %% [markdown]
# La distribución de datos se tiene debido a la naturaleza de los métodos de detección.

# %%
df = df.rename(columns={'detection_type': 'Método de Detección'})
#df.info()

# %%
a4_dims = (12.5, 7)
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.scatterplot(ax=ax, x="semi_major_axis", y="mass", hue="Método de Detección", data=df, 
                     palette='Paired', s=40)
ax.set_xlabel("Semi Eje Mayor [UA]")
ax.set_ylabel("Masa Planetaria [MJupiter]")
ax.set_title("Masa Planetaria en Función del Semi Eje Mayor")
ax.semilogx()
ax.vlines(x=1, ymin=0, ymax=80, linewidth=2, color='r')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.45))
plt.show()

# %% [markdown]
# Se observa que los métodos de detección tienen límites ahora de observar los diferentes tipos de planetas.

# %% [markdown]
# # ¿Se detectan planetas en todos los tipos de espectro de las estrellas?

# %% [markdown]
# ![Tipos de Espectro](http://k36.kn3.net/E0CF6C6C0.jpg)

# %%
df['star_sp_type'].value_counts().head(40).plot(kind='bar',title='tipo espectral',figsize=(15,5), color='navy')
plt.plot()
# Out:
# []

# %%
df['Método de Detección'].value_counts()
# Out:
# Primary Transit         3125
# Radial Velocity          913
# Imaging                  143
# Microlensing             134
# Timing                    45
# TTV                       18
# Astrometry                14
# Default                    9
# Primary Transit, TTV       2
# Controversial              1
# Name: Método de Detección, dtype: int64

# %% [markdown]
# # Tercer Ley de Keppler $T^2=C a^3$

# %% [markdown]
# Según la mecánica celeste clásica estos planetas deben cumplir con que  el cuadrado del Periodo es proporcional al cubo del Semieje Mayor.

# %%
df['orbital_period']= df['orbital_period'].apply(lambda x: x*x )

df['semi_major_axis']= df['semi_major_axis'].apply(lambda x: x*x*x )

# %%
ax = df.plot(kind='scatter', x='semi_major_axis', y='orbital_period', s=50, figsize=(14.8,5),logx=False, color='b')
ax.set_xlim(-100, 2000)
ax.set_ylim(-10**7, 2.5*10**8)
ax.set_xlabel("SemiEje Mayor $[UA]^3$")
ax.set_ylabel("Periodo Orbital $[Yrs]^2$")
ax.set_title("Periodo Orbital al Cuadrado en Función del SemiEje Mayor")
ax.plot()
# Out:
# []
